# %%
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import pandas as pd 


df = pd.read_csv("../Data/raw/homenest_reviews.csv")
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_text(text):
    text = text.lower()
    text = re.sub(r'http\S+|www\S+', '', text)
    text = re.sub(r'[^a-z0-9\s]', '', text)
    text = re.sub(r'<.*?>', '', text)
    text = re.sub(r'[^a-zA-Z]', ' ', text)
    words = text.split()
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]
    return " ".join(words)

df['cleaned_review'] = df['review_text'].apply(clean_text)

df.head()
# Out:
#    review_id    product_category                    product_name  \
# 0          1   Bedroom Furniture  DreamRest Memory Foam Mattress
# 1          2  Kitchen Appliances          InstaBrew Coffee Maker
# 2          3         Living Room            GlowLight Floor Lamp
# 3          4         Living Room      CozySofa L-Shape Sectional
# 4          5  Kitchen Appliances             TurboBlend Pro 5000
#
#                                          review_text  star_rating review_date  \
# 0  My DreamRest Memory Foam Mattress arrived well...            5  2024-02-08
# 1  The InstaBrew Coffee Maker itself is fine but ...            2  2023-09-11
# 2  My GlowLight Floor Lamp arrived well packaged ...            5  2023-07-03
# 3  The CozySofa L-Shape Sectional is okay. Does w...            3  2023-06-30
# 4  Delivery took 3 weeks and the TurboBlend Pro 5...            3  2024-09-23
#
#    verified_purchase                                     cleaned_review
# 0              False  dreamrest memory foam mattress arrived well pa...
# 1              False  instabrew coffee maker fine packaging complete...
# 2              False  glowlight floor lamp arrived well packaged sta...
# 3               True  cozysofa lshape sectional okay say nothing spe...
# 4               True  delivery took week turboblend pro box crushed ...

# %%
df['cleaned_review']
# Out:
# 0       dreamrest memory foam mattress arrived well pa...
# 1       instabrew coffee maker fine packaging complete...
# 2       glowlight floor lamp arrived well packaged sta...
# 3       cozysofa lshape sectional okay say nothing spe...
# 4       delivery took week turboblend pro box crushed ...
#                               ...
# 4995    nightowl led bedside lamp arrived well package...
# 4996    dreamrest memory foam mattress arrived time wo...
# 4997    great product glowlight floor lamp exceeded ex...
# 4998    five star airpurifier promax well built easy s...
# 4999    best purchase made year glowlight floor lamp w...
# Name: cleaned_review, Length: 5000, dtype: str
